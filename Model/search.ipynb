# %% [markdown]
# Let's take a look into the dataset good_reads.json

# %%
#counts the no. of lines in a file

# !wc -l goodreads_books.json.gz
# Out:
# 7588375 goodreads_books.json.gz

# %%
# How large this book is, in terms of file size
# To show all the files in the directory and search only the specific file.

# !ls -lh | grep goodreads_books.json.gz
# Out:
# -rw-r--r-- 1 ashis 197609 2.0G Sep 17 22:12 goodreads_books.json.gz

# %% [markdown]
# To compress the dataset

# %%
# In Streaming fashion i.e. line by line reading

import gzip

with gzip.open("goodreads_books.json.gz",'r') as f:
    line = f.readline() # to read single line

# %%
line # a single line
# Out:
# b'{"isbn": "", "text_reviews_count": "2", "series": [], "country_code": "US", "language_code": "ara", "popular_shelves": [{"count": "48397", "name": "to-read"}, {"count": "4724", "name": "classics"}, {"count": "3343", "name": "plays"}, {"count": "2412", "name": "currently-reading"}, {"count": "1734", "name": "shakespeare"}, {"count": "1373", "name": "drama"}, {"count": "1165", "name": "favorites"}, {"count": "1052", "name": "fiction"}, {"count": "706", "name": "classic"}, {"count": "635", "name": "play"}, {"count": "425", "name": "literature"}, {"count": "424", "name": "books-i-own"}, {"count": "412", "name": "owned"}, {"count": "411", "name": "school"}, {"count": "408", "name": "theatre"}, {"count": "263", "name": "poetry"}, {"count": "232", "name": "tragedy"}, {"count": "225", "name": "read-for-school"}, {"count": "212", "name": "british"}, {"count": "182", "name": "for-school"}, {"count": "165", "name": "theater"}, {"count": "159", "name": "english"}, {"count": "155", "name": "owned-books"}, {"count": "151", "name": "british-literature"}, {"count": "131", "name": "favourites"}, {"count": "130", "name": "classic-literature"}, {"count": "126", "name": "school-books"}, {"count": "117", "name": "college"}, {"count": "117", "name": "high-school"}, {"count": "112", "name": "english-literature"}, {"count": "106", "name": "historical-fiction"}, {"count": "104", "name": "teatro"}, {"count": "96", "name": "william-shakespeare"}, {"count": "95", "name": "17th-century"}, {"count": "94", "name": "default"}, {"count": "80", "name": "my-library"}, {"count": "76", "name": "england"}, {"count": "75", "name": "historical"}, {"count": "69", "name": "university"}, {"count": "69", "name": "adult"}, {"count": "69", "name": "british-lit"}, {"count": "65", "name": "brit-lit"}, {"count": "62", "name": "classics-to-read"}, {"count": "62", "name": "library"}, {"count": "61", "name": "school-reads"}, {"count": "60", "name": "to-buy"}, {"count": "59", "name": "i-own"}, {"count": "59", "name": "classic-lit"}, {"count": "57", "name": "renaissance"}, {"count": "52", "name": "my-books"}, {"count": "48", "name": "english-lit"}, {"count": "48", "name": "required-reading"}, {"count": "47", "name": "uni"}, {"count": "47", "name": "school-reading"}, {"count": "46", "name": "re-read"}, {"count": "43", "name": "own-it"}, {"count": "41", "name": "novels"}, {"count": "41", "name": "ap-lit"}, {"count": "39", "name": "uk"}, {"count": "39", "name": "classic-fiction"}, {"count": "36", "name": "for-class"}, {"count": "36", "name": "home-library"}, {"count": "35", "name": "read-in-2016"}, {"count": "35", "name": "read-in-2015"}, {"count": "35", "name": "literary"}, {"count": "34", "name": "read-in-2014"}, {"count": "34", "name": "read-in-school"}, {"count": "33", "name": "ebooks"}, {"count": "33", "name": "to-read-classics"}, {"count": "33", "name": "the-classics"}, {"count": "33", "name": "lit"}, {"count": "32", "name": "my-ebooks"}, {"count": "32", "name": "drama-plays"}, {"count": "31", "name": "family"}, {"count": "31", "name": "kindle"}, {"count": "31", "name": "literary-fiction"}, {"count": "30", "name": "read-in-2017"}, {"count": "30", "name": "audiobook"}, {"count": "29", "name": "adult-fiction"}, {"count": "29", "name": "assigned-reading"}, {"count": "28", "name": "read-in-english"}, {"count": "28", "name": "poetry-and-plays"}, {"count": "28", "name": "all-time-favorites"}, {"count": "28", "name": "to-re-read"}, {"count": "26", "name": "1600s"}, {"count": "26", "name": "books"}, {"count": "26", "name": "plays-and-poetry"}, {"count": "26", "name": "history"}, {"count": "26", "name": "poetry-plays"}, {"count": "25", "name": "reread"}, {"count": "25", "name": "personal-library"}, {"count": "25", "name": "early-modern"}, {"count": "25", "name": "read-more-than-once"}, {"count": "25", "name": "scripts"}, {"count": "24", "name": "classics-read"}, {"count": "23", "name": "favorite"}, {"count": "23", "name": "to-reread"}, {"count": "23", "name": "class"}, {"count": "23" ...

# %%
# Use json module to load the single line in a Python dictionary

import json

json.loads(line)
# Out:
# {'isbn': '',
#  'text_reviews_count': '2',
#  'series': [],
#  'country_code': 'US',
#  'language_code': 'ara',
#  'popular_shelves': [{'count': '48397', 'name': 'to-read'},
#   {'count': '4724', 'name': 'classics'},
#   {'count': '3343', 'name': 'plays'},
#   {'count': '2412', 'name': 'currently-reading'},
#   {'count': '1734', 'name': 'shakespeare'},
#   {'count': '1373', 'name': 'drama'},
#   {'count': '1165', 'name': 'favorites'},
#   {'count': '1052', 'name': 'fiction'},
#   {'count': '706', 'name': 'classic'},
#   {'count': '635', 'name': 'play'},
#   {'count': '425', 'name': 'literature'},
#   {'count': '424', 'name': 'books-i-own'},
#   {'count': '412', 'name': 'owned'},
#   {'count': '411', 'name': 'school'},
#   {'count': '408', 'name': 'theatre'},
#   {'count': '263', 'name': 'poetry'},
#   {'count': '232', 'name': 'tragedy'},
#   {'count': '225', 'name': 'read-for-school'},
#   {'count': '212', 'name': 'british'},
#   {'count': '182', 'name': 'for-school'},
#   {'count': '165', 'name': 'theater'},
#   {'count': '159', 'name': 'english'},
#   {'count': '155', 'name': 'owned-books'},
#   {'count': '151', 'name': 'british-literature'},
#   {'count': '131', 'name': 'favourites'},
#   {'count': '130', 'name': 'classic-literature'},
#   {'count': '126', 'name': 'school-books'},
#   {'count': '117', 'name': 'college'},
#   {'count': '117', 'name': 'high-school'},
#   {'count': '112', 'name': 'english-literature'},
#   {'count': '106', 'name': 'historical-fiction'},
#   {'count': '104', 'name': 'teatro'},
#   {'count': '96', 'name': 'william-shakespeare'},
#   {'count': '95', 'name': '17th-century'},
#   {'count': '94', 'name': 'default'},
#   {'count': '80', 'name': 'my-library'},
#   {'count': '76', 'name': 'england'},
#   {'count': '75', 'name': 'historical'},
#   {'count': '69', 'name': 'university'},
#   {'count': '69', 'name': 'adult'},
#   {'count': '69', 'name': 'british-lit'},
#   {'count': '65', 'name': 'brit-lit'},
#   {'count': '62', 'name': 'classics-to-read'},
#   {'count': '62', 'name': 'library'},
#   {'count': '61', 'name': 'school-reads'},
#   {'count': '60', 'name': 'to-buy'},
#   {'count': '59', 'name': 'i-own'},
#   {'count': '59', 'name': 'classic-lit'},
#   {'count': '57', 'name': 'renaissance'},
#   {'count': '52', 'name': 'my-books'},
#   {'count': '48', 'name': 'english-lit'},
#   {'count': '48', 'name': 'required-reading'},
#   {'count': '47', 'name': 'uni'},
#   {'count': '47', 'name': 'school-reading'},
#   {'count': '46', 'name': 're-read'},
#   {'count': '43', 'name': 'own-it'},
#   {'count': '41', 'name': 'novels'},
#   {'count': '41', 'name': 'ap-lit'},
#   {'count': '39', 'name': 'uk'},
#   {'count': '39', 'name': 'classic-fiction'},
#   {'count': '36', 'name': 'for-class'},
#   {'count': '36', 'name': 'home-library'},
#   {'count': '35', 'name': 'read-in-2016'},
#   {'count': '35', 'name': 'read-in-2015'},
#   {'count': '35', 'name': 'literary'},
#   {'count': '34', 'name': 'read-in-2014'},
#   {'count': '34', 'name': 'read-in-school'},
#   {'count': '33', 'name': 'ebooks'},
#   {'count': '33', 'name': 'to-read-classics'},
#   {'count': '33', 'name': 'the-classics'},
#   {'count': '33', 'name': 'lit'},
#   {'count': '32', 'name': 'my-ebooks'},
#   {'count': '32', 'name': 'drama-plays'},
#   {'count': '31', 'name': 'family'},
#   {'count': '31', 'name': 'kindle'},
#   {'count': '31', 'name': 'literary-fiction'},
#   {'count': '30', 'name': 'read-in-2017'},
#   {'count': '30', 'name': 'audiobook'},
#   {'count': '29', 'name': 'adult-fiction'},
#   {'count': '29', 'name': 'assigned-reading'},
#   {'count': '28', 'name': 'read-in-english'},
#   {'count': '28', 'name': 'poetry-and-plays'},
#   {'count': '28', 'name': 'all-time-favorites'},
#   {'count': '28', 'name': 'to-re-read'},
#   {'count': '26', 'name': '1600s'},
#   {'count': '26', 'name': 'books'},
#   {'count': '26', 'name': 'plays-and-poetry'},
#   {'count': '26', 'name': 'history'},
#   {'count': '26', 'name': 'poetry-plays'},
#   {'count': '25', 'name': 'reread'},
#   {'count': '25', 'name': 'personal-library'},
#   {'count': '25', 'name': 'early-modern'},
#   {'count': '25', 'name': 'read-more-than-once'},
#   {'count': '25', 'name': 'scripts'},
#   {'count': '24', 'name': 'classics-read'},
#   {'count': '23', 'name': 'favorite'},
#   {'count': '23', 'name': 'to-reread'},
#   {'count': '23', 'name': 'class'},
#   {'count': '23', 'name': 'great-books'},
#   {'count': '23', 'name': 'read-for-class'}],
#  'asin': '',
#  'is_ebook': 'false',
#  'average_rating': '3.90',
#  'kindle_asin': '',
#  'similar_books': ['351605',
#   '494785',
#   '148313',
#   '111734',
#   '143513',
#   '383337',
#   '209186',
#   '752868',
#   '118327',
#   '54028',
#   '1042903',
#   '161915',
#   '12274',
#   '258123',
#   '40107',
#   '279221',
#   '384597'],
#  'description': "King Lear, growing old and too tired to reign, decides to divide his realm amongst his three daughters, leaving the largest share to the one who loves him the most. His two eldest daughters, Goneril and Regan, foolish and deceitful children, are rewarded for their insincere flattery. His youngest daughter, Cordelia, however, speaks honestly and truthfully, which enrages the old king. He disinherits Cordelia, and then drives himself to madness, left to wander the heath with only his Fool, his servant Caius, and the madman Tom O'Bedlam for company. Once reunited with Cordelia, Lear is too late repents his rashness, and must face the tragic consequences of his choices.",
#  'format': 'Paperback',
#  'link': 'https://www.goodreads.com/book/show/29569314',
#  'authors': [{'author_id': '947', 'role': ''},
#   {'author_id': '15100624', 'role': 'trjm@'}],
#  'publisher': 'lmrkz lqwmy lltrjm@',
#  'num_pages': '146',
#  'publication_day': '',
#  'isbn13': '9789777041188',
#  'publication_month': '',
#  'edition_information': "lTb`@ l'wl~",
#  'publication_year': '2012',
#  'url': 'https://www.goodreads.com/book/show/29569314',
#  'image_url': 'https://images.gr-assets.com/books/1458595755m/29569314.jpg',
#  'book_id': '29569314',
#  'ratings_count': '3',
#  'work_id': '2342136',
#  'title': 'الملك لير',
#  'title_without_series': 'الملك لير'}

# %% [markdown]
# PARSING OUR BOOK METADATA

# %%
# Let's scale up the technique

def parse_fields(line): # it will only return the fields we care about
    data = json.loads(line)
    return {
        "book_id": data["book_id"],
        "title": data["title_without_series"],
        "ratings": data["ratings_count"],
        "url": data["url"],
        "cover_image": data["image_url"]
    }

# %%
# To create a way to go line by line and parse each line

books_titles = []

with gzip.open("goodreads_books.json.gz", 'r') as f:
    while True:
        line = f.readline() # runs a single line
        if not line:
            break
        fields = parse_fields(line)
        
        try:
            ratings = int(fields["ratings"])
        except ValueError:
            continue
        if ratings > 15:
            books_titles.append(fields)

# %% [markdown]
# PROCESSING BOOK METADATA WITH PYTHON-PANDAS

# %%
import pandas as pd

titles = pd.DataFrame.from_dict(books_titles)

# %%
# Turn title_rating into a numerical column to do comparision

titles["ratings"] = pd.to_numeric(titles["ratings"])

# %% [markdown]
# To construct a search engine we want to minimize our search engine as much as possible. The way we do that by minimizing the number of characters.

# %%
titles["mod_title"] = titles["title"].str.replace("[^a-zA-Z0-9]","", regex = True)

# %%
titles
# Out:
#           book_id                                              title  ratings  \
# 0         7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 1         6066819                               Best Friends Forever    51184
# 2          287141                      The Aeneid for Boys and Girls       46
# 3         6066812  All's Fairy in Love and War (Avalon: Web of Ma...       98
# 4          287149                               The Devil's Notebook      986
# ...           ...                                                ...      ...
# 1308952  17805813                      Ondine (Ondine Quartet, #0.5)      327
# 1308953    331839     Jacqueline Kennedy Onassis: Friend of the Arts       18
# 1308954   2685097                   The Spaniard's Blackmailed Bride      112
# 1308955   2342551           The Children's Classic Poetry Collection       36
# 1308956  22017381          101 Nights: Volume One (101 Nights, #1-3)       70
#
#                                                        url  \
# 0        https://www.goodreads.com/book/show/7327624-th...
# 1        https://www.goodreads.com/book/show/6066819-be...
# 2        https://www.goodreads.com/book/show/287141.The...
# 3        https://www.goodreads.com/book/show/6066812-al...
# 4        https://www.goodreads.com/book/show/287149.The...
# ...                                                    ...
# 1308952  https://www.goodreads.com/book/show/17805813-o...
# 1308953  https://www.goodreads.com/book/show/331839.Jac...
# 1308954  https://www.goodreads.com/book/show/2685097-th...
# 1308955  https://www.goodreads.com/book/show/2342551.Th...
# 1308956  https://www.goodreads.com/book/show/22017381-1...
#
#                                                cover_image  \
# 0        https://images.gr-assets.com/books/1304100136m...
# 1        https://s.gr-assets.com/assets/nophoto/book/11...
# 2        https://s.gr-assets.com/assets/nophoto/book/11...
# 3        https://images.gr-assets.com/books/1316637798m...
# 4        https://images.gr-assets.com/books/1328768789m...
# ...                                                    ...
# 1308952  https://images.gr-assets.com/books/1379766592m...
# 1308953  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308954  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308955  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308956  https://images.gr-assets.com/books/1398621236m...
#
#                                        mod_title
# 0        TheUnschooledWizardSunWolfandStarhawk12
# 1                             BestFriendsForever
# 2                       TheAeneidforBoysandGirls
# 3         AllsFairyinLoveandWarAvalonWebofMagic8
# 4                              TheDevilsNotebook
# ...                                          ...
# 1308952                    OndineOndineQuartet05
# 1308953  JacquelineKennedyOnassisFriendoftheArts
# 1308954             TheSpaniardsBlackmailedBride
# 1308955      TheChildrensClassicPoetryCollection
# 1308956            101NightsVolumeOne101Nights13
#
# [1308957 rows x 6 columns]

# %%
titles["mod_title"] = titles["mod_title"].str.lower()

# %%
titles["mod_title"] = titles["mod_title"].str.replace("\s+"," ", regex = True)

# %%
titles
# Out:
#           book_id                                              title  ratings  \
# 0         7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 1         6066819                               Best Friends Forever    51184
# 2          287141                      The Aeneid for Boys and Girls       46
# 3         6066812  All's Fairy in Love and War (Avalon: Web of Ma...       98
# 4          287149                               The Devil's Notebook      986
# ...           ...                                                ...      ...
# 1308952  17805813                      Ondine (Ondine Quartet, #0.5)      327
# 1308953    331839     Jacqueline Kennedy Onassis: Friend of the Arts       18
# 1308954   2685097                   The Spaniard's Blackmailed Bride      112
# 1308955   2342551           The Children's Classic Poetry Collection       36
# 1308956  22017381          101 Nights: Volume One (101 Nights, #1-3)       70
#
#                                                        url  \
# 0        https://www.goodreads.com/book/show/7327624-th...
# 1        https://www.goodreads.com/book/show/6066819-be...
# 2        https://www.goodreads.com/book/show/287141.The...
# 3        https://www.goodreads.com/book/show/6066812-al...
# 4        https://www.goodreads.com/book/show/287149.The...
# ...                                                    ...
# 1308952  https://www.goodreads.com/book/show/17805813-o...
# 1308953  https://www.goodreads.com/book/show/331839.Jac...
# 1308954  https://www.goodreads.com/book/show/2685097-th...
# 1308955  https://www.goodreads.com/book/show/2342551.Th...
# 1308956  https://www.goodreads.com/book/show/22017381-1...
#
#                                                cover_image  \
# 0        https://images.gr-assets.com/books/1304100136m...
# 1        https://s.gr-assets.com/assets/nophoto/book/11...
# 2        https://s.gr-assets.com/assets/nophoto/book/11...
# 3        https://images.gr-assets.com/books/1316637798m...
# 4        https://images.gr-assets.com/books/1328768789m...
# ...                                                    ...
# 1308952  https://images.gr-assets.com/books/1379766592m...
# 1308953  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308954  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308955  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308956  https://images.gr-assets.com/books/1398621236m...
#
#                                        mod_title
# 0        theunschooledwizardsunwolfandstarhawk12
# 1                             bestfriendsforever
# 2                       theaeneidforboysandgirls
# 3         allsfairyinloveandwaravalonwebofmagic8
# 4                              thedevilsnotebook
# ...                                          ...
# 1308952                    ondineondinequartet05
# 1308953  jacquelinekennedyonassisfriendofthearts
# 1308954             thespaniardsblackmailedbride
# 1308955      thechildrensclassicpoetrycollection
# 1308956            101nightsvolumeone101nights13
#
# [1308957 rows x 6 columns]

# %%
titles = titles[titles["mod_title"].str.len() > 0]

# %%
titles.to_json("books_titles.json")

# %%
titles
# Out:
#           book_id                                              title  ratings  \
# 0         7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 1         6066819                               Best Friends Forever    51184
# 2          287141                      The Aeneid for Boys and Girls       46
# 3         6066812  All's Fairy in Love and War (Avalon: Web of Ma...       98
# 4          287149                               The Devil's Notebook      986
# ...           ...                                                ...      ...
# 1308952  17805813                      Ondine (Ondine Quartet, #0.5)      327
# 1308953    331839     Jacqueline Kennedy Onassis: Friend of the Arts       18
# 1308954   2685097                   The Spaniard's Blackmailed Bride      112
# 1308955   2342551           The Children's Classic Poetry Collection       36
# 1308956  22017381          101 Nights: Volume One (101 Nights, #1-3)       70
#
#                                                        url  \
# 0        https://www.goodreads.com/book/show/7327624-th...
# 1        https://www.goodreads.com/book/show/6066819-be...
# 2        https://www.goodreads.com/book/show/287141.The...
# 3        https://www.goodreads.com/book/show/6066812-al...
# 4        https://www.goodreads.com/book/show/287149.The...
# ...                                                    ...
# 1308952  https://www.goodreads.com/book/show/17805813-o...
# 1308953  https://www.goodreads.com/book/show/331839.Jac...
# 1308954  https://www.goodreads.com/book/show/2685097-th...
# 1308955  https://www.goodreads.com/book/show/2342551.Th...
# 1308956  https://www.goodreads.com/book/show/22017381-1...
#
#                                                cover_image  \
# 0        https://images.gr-assets.com/books/1304100136m...
# 1        https://s.gr-assets.com/assets/nophoto/book/11...
# 2        https://s.gr-assets.com/assets/nophoto/book/11...
# 3        https://images.gr-assets.com/books/1316637798m...
# 4        https://images.gr-assets.com/books/1328768789m...
# ...                                                    ...
# 1308952  https://images.gr-assets.com/books/1379766592m...
# 1308953  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308954  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308955  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308956  https://images.gr-assets.com/books/1398621236m...
#
#                                        mod_title
# 0        theunschooledwizardsunwolfandstarhawk12
# 1                             bestfriendsforever
# 2                       theaeneidforboysandgirls
# 3         allsfairyinloveandwaravalonwebofmagic8
# 4                              thedevilsnotebook
# ...                                          ...
# 1308952                    ondineondinequartet05
# 1308953  jacquelinekennedyonassisfriendofthearts
# 1308954             thespaniardsblackmailedbride
# 1308955      thechildrensclassicpoetrycollection
# 1308956            101nightsvolumeone101nights13
#
# [1264933 rows x 6 columns]

# %% [markdown]
# BUILDING THE BOOK SEARCH ENGINE

# %%
# To create "Term Frequency", "Inverse Document Frequency", and finally Tf*Idf

from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()

tfidf = vectorizer.fit_transform(titles["mod_title"])

# %%
#To do comparision 

from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import re

def make_clickable(val):
    return '<a target="_blank" href="{}">Goodreads</a>'.format(val, val)

def show_image(val):
    return '<a href="{}"><img src="{}" width=50></img></a>'.format(val, val)

def search(query,vectorizer):
    processed = re.sub("[^a-zA-Z0-9 ]", "", query.lower())
    query_vec = vectorizer.transform([query])
    similarity = cosine_similarity(query_vec, tfidf).flatten()
    indices = np.argpartition(similarity, -10)[-10:]
    results = titles.iloc[indices]
    results = results.sort_values("ratings", ascending=False)
    
    return results.head(5).style.format({'url': make_clickable, 'cover_image': show_image})

# %%
search("All's Fairy in Love and War", vectorizer)
# Out:
# <style type="text/css">
# </style>
# <table id="T_644c8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_644c8_level0_col0" class="col_heading level0 col0" >book_id</th>
#       <th id="T_644c8_level0_col1" class="col_heading level0 col1" >title</th>
#       <th id="T_644c8_level0_col2" class="col_heading level0 col2" >ratings</th>
#       <th id="T_644c8_level0_col3" class="col_heading level0 col3" >url</th>
#       <th id="T_644c8_level0_col4" class="col_heading level0 col4" >cover_image</th>
#       <th id="T_644c8_level0_col5" class="col_heading level0 col5" >mod_title</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_644c8_level0_row0" class="row_heading level0 row0" >656512</th>
#       <td id="T_644c8_row0_col0" class="data row0 col0" >8575298</td>
#       <td id="T_644c8_row0_col1" class="data row0 col1" >War</td>
#       <td id="T_644c8_row0_col2" class="data row0 col2" >917</td>
#       <td id="T_644c8_row0_col3" class="data row0 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/8575298-war">Goodreads</a></td>
#       <td id="T_644c8_row0_col4" class="data row0 col4" ><a href="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png"><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></a></td>
#       <td id="T_644c8_row0_col5" class="data row0 col5" >war</td>
#     </tr>
#     <tr>
#       <th id="T_644c8_level0_row1" class="row_heading level0 row1" >406995</th>
#       <td id="T_644c8_row1_col0" class="data row1 col0" >6514664</td>
#       <td id="T_644c8_row1_col1" class="data row1 col1" >War</td>
#       <td id="T_644c8_row1_col2" class="data row1 col2" >333</td>
#       <td id="T_644c8_row1_col3" class="data row1 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/6514664-war">Goodreads</a></td>
#       <td id="T_644c8_row1_col4" class="data row1 col4" ><a href="https://images.gr-assets.com/books/1314464534m/6514664.jpg"><img src="https://images.gr-assets.com/books/1314464534m/6514664.jpg" width=50></img></a></td>
#       <td id="T_644c8_row1_col5" class="data row1 col5" >war</td>
#     </tr>
#     <tr>
#       <th id="T_644c8_level0_row2" class="row_heading level0 row2" >840752</th>
#       <td id="T_644c8_row2_col0" class="data row2 col0" >23167716</td>
#       <td id="T_644c8_row2_col1" class="data row2 col1" >In</td>
#       <td id="T_644c8_row2_col2" class="data row2 col2" >276</td>
#       <td id="T_644c8_row2_col3" class="data row2 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/23167716-in">Goodreads</a></td>
#       <td id="T_644c8_row2_col4" class="data row2 col4" ><a href="https://images.gr-assets.com/books/1413517029m/23167716.jpg"><img src="https://images.gr-assets.com/books/1413517029m/23167716.jpg" width=50></img></a></td>
#       <td id="T_644c8_row2_col5" class="data row2 col5" >in</td>
#     </tr>
#     <tr>
#       <th id="T_644c8_level0_row3" class="row_heading level0 row3" >1019009</th>
#       <td id="T_644c8_row3_col0" class="data row3 col0" >18040556</td>
#       <td id="T_644c8_row3_col1" class="data row3 col1" >Fairy</td>
#       <td id="T_644c8_row3_col2" class="data row3 col2" >93</td>
#       <td id="T_644c8_row3_col3" class="data row3 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/18040556-fairy">Goodreads</a></td>
#       <td id="T_644c8_row3_col4" class="data row3 col4" ><a href="https://images.gr-assets.com/books/1370414496m/18040556.jpg"><img src="https://images.gr-assets.com/books/1370414496m/18040556.jpg" width=50></img></a></td>
#       <td id="T_644c8_row3_col5" class="data row3 col5" >fairy</td>
#     </tr>
#     <tr>
#       <th id="T_644c8_level0_row4" class="row_heading level0 row4" >22786</th>
#       <td id="T_644c8_row4_col0" class="data row4 col0" >8173973</td>
#       <td id="T_644c8_row4_col1" class="data row4 col1" >War</td>
#       <td id="T_644c8_row4_col2" class="data row4 col2" >69</td>
#       <td id="T_644c8_row4_col3" class="data row4 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/8173973-war">Goodreads</a></td>
#       <td id="T_644c8_row4_col4" class="data row4 col4" ><a href="https://images.gr-assets.com/books/1344264627m/8173973.jpg"><img src="https://images.gr-assets.com/books/1344264627m/8173973.jpg" width=50></img></a></td>
#       <td id="T_644c8_row4_col5" class="data row4 col5" >war</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# CREATING THE LIST OF LIKED BOOKS

# %%
liked_books = ["17381863", "35005834", "6514664", "7327624", "331839"]
